# %%
pip install diffusers transformers torch matplotlib

# %%
from diffusers import StableDiffusionPipeline
import matplotlib.pyplot as plt
import torch

# Define model ID
model_id = "dreamlike-art/dreamlike-diffusion-1.0"

# Load the pipeline with the specified model, using float32 for CPU
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float32, use_safetensors=True)
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# Define your prompt
prompt = "A beautiful landscape"

# Generate the image
image = pipe(prompt).images[0]

# Display the image
plt.imshow(image)
plt.axis('off')  # Hide axes
plt.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
